# %%
import re
from collections import Counter
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import nltk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\HP ENVY
# [nltk_data]     X360\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\HP ENVY
# [nltk_data]     X360\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\HP ENVY
# [nltk_data]     X360\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text="Barack Obama was born in Hawaii. He served as the 44th President of the United States. Obama loves playing basketball in his free time"

# %%
text_lower=text.lower()
print('lowered text')
print(text_lower)
# Out:
# lowered text
# barack obama was born in hawaii. he served as the 44th president of the united states. obama loves playing basketball in his free time

# %%
text_no_punct=re.sub(r'[^\w\s]','',text_lower)
print('text without punctuation')
print(text_no_punct)
# Out:
# text without punctuation
# barack obama was born in hawaii he served as the 44th president of the united states obama loves playing basketball in his free time

# %%
stop_word=set(stopwords.words("english"))
tokens_clean=[word for word in token if word not in stop_word and word not in string.punctuation]

# %%
word_freq=Counter(tokens_clean)
top_words=word_freq.most_common(10)
words , counts = zip(*top_words)

# %%
plt.figure(figsize=(12,7))
plt.bar(words ,counts,color="skyblue")
plt.title("top 10 words")
plt.xlabel('words')
plt.ylabel('Frequency')
plt.show()
