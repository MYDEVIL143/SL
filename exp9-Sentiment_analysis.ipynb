# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Siddhesh\AppData\Roaming\nltk_data...
# True

# %%
senti=SentimentIntensityAnalyzer()

# %%
texts = [
 "I love this product!",
 "This is the worst movie ever.",
 "It's okay, not great though.",
 "Absolutely fantastic experience.",
 "I hate this so much."
 ]

# %%
for text in texts:
 scores=senti.polarity_scores(text)
 print("\nText:",texts)
 print("Sentiment Scores:",scores)
# Out:
# Text: ['I love this product!', 'This is the worst movie ever.', "It's okay, not great though.", 'Absolutely fantastic experience.', 'I hate this so much.']
# Sentiment Scores: {'neg': 0.0, 'neu': 0.308, 'pos': 0.692, 'compound': 0.6696}
#
# Text: ['I love this product!', 'This is the worst movie ever.', "It's okay, not great though.", 'Absolutely fantastic experience.', 'I hate this so much.']
# Sentiment Scores: {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}
#
# Text: ['I love this product!', 'This is the worst movie ever.', "It's okay, not great though.", 'Absolutely fantastic experience.', 'I hate this so much.']
# Sentiment Scores: {'neg': 0.402, 'neu': 0.366, 'pos': 0.232, 'compound': -0.3387}
#
# Text: ['I love this product!', 'This is the worst movie ever.', "It's okay, not great though.", 'Absolutely fantastic experience.', 'I hate this so much.']
# Sentiment Scores: {'neg': 0.0, 'neu': 0.339, 'pos': 0.661, 'compound': 0.5984}
#
# Text: ['I love this product!', 'This is the worst movie ever.', "It's okay, not great though.", 'Absolutely fantastic experience.', 'I hate this so much.']
# Sentiment Scores: {'neg': 0.552, 'neu': 0.448, 'pos': 0.0, 'compound': -0.5719}

# %%
compound = scores['compound']
if compound >= 0.05:
     sentiment = "Positive"
elif compound <=-0.05:
     sentiment = "Negative"
else:
     sentiment = "Neutral"

print("Compound Score:",compound)
print("Predicted sentiment:",sentiment)
# Out:
# Compound Score: -0.5719
# Predicted sentiment: Negative
